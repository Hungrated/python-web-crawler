# %%
# 数据清洗进阶

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string

def cleanInput(input):
    input = re.sub('\n+', " ", input)
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = bytes(input, "UTF-8")
    input = input.decode("ascii", "ignore")
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            cleanInput.append(item)
    return cleanInput
def ngrams(input, n):
    input = cleanInput(input)
    output = []
    for i in range(len(input)-n+1):
        output.append(input[i:i+n])
    return output

# %%
html = urlopen("http://en.wikipedia.org/wiki/Python_(programming_language)")
bsObj = BeautifulSoup(html, features='lxml')
content = bsObj.find("div", {"id":"mw-content-text"}).get_text()

# %%
myngrams = ngrams(content, 2)
print(myngrams)
print("2-grams count is: "+str(len(myngrams)))
# Out:
# [['Python', 'Paradigm'], ['Paradigm', 'Object-oriented'], ['Object-oriented', 'imperative'], ['imperative', 'functional'], ['functional', 'procedural'], ['procedural', 'reflectiveDesignedby'], ['reflectiveDesignedby', 'Guido'], ['Guido', 'van'], ['van', 'RossumDeveloper'], ['RossumDeveloper', 'Python'], ['Python', 'Software'], ['Software', 'FoundationFirstappeared'], ['FoundationFirstappeared', '1990'], ['1990', '28years'], ['28years', 'ago(1990'], ['ago(1990', 'Stable'], ['Stable', 'release'], ['release', '3.7.0'], ['3.7.0', '27June'], ['27June', '2018'], ['2018', '43'], ['43', 'days'], ['days', 'ago(2018-06-27)2.7.15'], ['ago(2018-06-27)2.7.15', '1May'], ['1May', '2018'], ['2018', 'months'], ['months', 'ago(2018-05-01'], ['ago(2018-05-01', 'Typing'], ['Typing', 'discipline'], ['discipline', 'Duck'], ['Duck', 'dynamic'], ['dynamic', 'strong'], ['strong', 'since'], ['since', 'version'], ['version', '3.5'], ['3.5', 'GradualLicense'], ['GradualLicense', 'Python'], ['Python', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions'], ['extensions', 'py'], ['py', 'pyc'], ['pyc', 'pyd'], ['pyd', 'pyo'], ['pyo', 'prior'], ['prior', 'to'], ['to', '3.5'], ['3.5', 'pyw'], ['pyw', 'pyz'], ['pyz', 'since'], ['since', '3.5)Website'], ['3.5)Website', 'www.python.orgMajor'], ['www.python.orgMajor', 'implementations'], ['implementations', 'CPython'], ['CPython', 'IronPython'], ['IronPython', 'Jython'], ['Jython', 'MicroPython'], ['MicroPython', 'Numba'], ['Numba', 'PyPy'], ['PyPy', 'Stackless'], ['Stackless', 'PythonDialects'], ['PythonDialects', 'Cython'], ['Cython', 'RPythonInfluenced'], ['RPythonInfluenced', 'by'], ['by', 'ABC'], ['ABC', 'ALGOL'], ['ALGOL', '68'], ['68', 'CLU'], ['CLU', 'Dylan'], ['Dylan', 'Haskell'], ['Haskell', 'Icon'], ['Icon', 'Java'], ['Java', 'Lisp'], ['Lisp', 'Modula-3'], ['Modula-3', 'PerlInfluenced'], ['PerlInfluenced', 'Boo'], ['Boo', 'Cobra'], ['Cobra', 'CoffeeScript'], ['CoffeeScript', 'Falcon'], ['Falcon', 'Genie'], ['Genie', 'Go'], ['Go', 'Apache'], ['Apache', 'Groovy'], ['Groovy', 'JavaScript'], ['JavaScript', 'Julia'], ['Julia', 'Nim'], ['Nim', 'Ring'], ['Ring', 'Ruby'], ['Ruby', 'Swift'], ['Swift', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks'], ['Wikibooks', 'Python'], ['Python', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'programming'], ['programming', 'language'], ['language', 'for'], ['for', 'general-purpose'], ['general-purpose', 'programming'], ['programming', 'Created'], ['Created', 'by'], ['by', 'Guido'], ['Guido', 'van'], ['van', 'Rossum'], ['Rossum', 'and'], ['and', 'first'], ['first', 'released'], ['released', 'in'], ['in', '1991'], ['1991', 'Python'], ['Python', 'has'], ['has', 'a'], ['a', 'design'], ['design', 'philosophy'], ['philosophy', 'that'], ['that', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability'], ['readability', 'notably'], ['notably', 'using'], ['using', 'significant'], ['significant', 'whitespace'], ['whitespace', 'It'], ['It', 'provides'], ['provides', 'constructs'], ['constructs', 'that'], ['that', 'enable'], ['enable', 'clear'], ['clear', 'programming'], ['programming', 'on'], ['on', 'both'], ['both', 'small'], ['small', 'and'], ['and', 'large'], ['large', 'scales'], ['scales', 'In'], ['In', 'July'], ['July', '2018'], ['2018', 'Van'], ['Van', 'Rossum'], ['Rossum', 'stepped'], ['stepped', 'down'], ['down', 'as'], ['as', 'the'], ['the', 'leader'], ['leader', 'in'], ['in', 'the'], ['the', 'language'], ['language', 'community'], ['community', 'after'], ['after', '30'], ['30', 'years'], ['years', 'Python'], ['Python', 'features'], ['features', 'a'], ['a', 'dynamic'], ['dynamic', 'type'], ['type', 'system'], ['system', 'and'], ['and', 'automatic'], ['automatic', 'memory'], ['memory', 'management'], ['management', 'It'], ['It', 'supports'], ['supports', 'multiple'], ['multiple', 'programming'], ['programming', 'paradigms'], ['paradigms', 'i ...
# 2-grams count is: 8876

# %%
from collections import OrderedDict

myngramsSorted = OrderedDict(sorted(dict(myngrams).items(), key=lambda t: t[1], reverse=True))
print(myngramsSorted)
# Out:
# OrderedDict([('WTFPL', 'zlib'), ('As', 'you'), ('3.5)Website', 'www.python.orgMajor'), ('Counts', 'www.modulecounts.com'), ('Canopy', 'www.enthought.com'), ('originally', 'written'), ('installers', 'written'), ('office', 'would'), ('result', 'would'), ('expression', 'would'), ('game', 'world'), ('combinatorial', 'workload'), ('announced', 'work'), ('do', 'with'), ('interfacing', 'with'), ('backward-compatible', 'with'), ('designed', 'with'), ('frustrations', 'with'), ('conforms', 'with'), ('structure', 'with'), ('along', 'with'), ('performed', 'with'), ('arithmetic', 'with'), ('consistent', 'with'), ('compared', 'with'), ('computing', 'with'), ('distributed', 'with'), ('integrates', 'with'), ('integrate', 'with'), ('corresponds', 'with'), ('ships', 'with'), ('Interview', 'with'), ('record', 'with'), ('procedure', 'with'), ('modders', 'with'), ('Trading', 'with'), ('Working', 'with'), ('never', 'will'), ('Wiki', 'wiki.ecmascript.org'), ('enjoyed', 'while'), ('ABC', 'which'), ('utility', 'which'), ('operators', 'which'), ('yields', 'which'), ('PyGTK', 'which'), ('versions', 'where'), ('unpacking', 'where'), ('useful', 'where'), ('made', 'when'), ('interval', 'when'), ('idioms', 'well'), ('Julia', 'website'), ('Official', 'website'), ('Webware', 'web2py'), ('vtePython', 'web'), ('oneobvious', 'way'), ('pyo', 'was'), ('that', 'was'), ('SETL', 'was'), ('py3k', 'was'), ('date', 'was'), ('portability', 'was'), ('workload', 'was'), ('consumption', 'was'), ('Schedules', 'was'), ('Non-English-based', 'vtePythonImplementations'), ('PyCon', 'vtePython'), ('DMOZ', 'vteProgramming'), ('more', 'vteFree'), ('eval', 'vs'), ("Rossum's", 'vision'), ('create', 'video-games'), ('several', 'video'), ('e.g', 'via'), ('Coroutines', 'via'), ('Gratis', 'versus'), ('previous', 'versions'), ('tie-breaking', 'versions'), ('Backward-incompatible', 'versions'), ('Before', 'version'), ('stackless', 'version'), ('contains', 'various'), ('all', 'variants'), ('metasyntactic', 'variables'), ('left-hand', 'variable'), ('untyped', 'variable'), ('Moshe', 'van'), ('produced', 'values'), ('right-hand', 'value'), ('indicated', 'value'), ('Boolean', 'value'), ('syntactically', 'valid'), ('permanent', 'vacation'), ('API', 'v1.0'), ('Interface', 'v1.0'), ('Guide', 'v1.0'), ('2to3', 'utility'), ('fixed-precision', 'usually'), ('notably', 'using'), ('Brokers', 'using'), ('Boo', 'uses'), ('Debugger', 'uses'), ('Ubuntu', 'uses'), ('UNIX', 'users'), ('main', 'user-programming'), ('graphical', 'user'), ('Graphical', 'user'), ('be', 'used'), ('often', 'used'), ('symbolic', 'used'), ('commonly', 'used'), ('earlier', 'use'), ('effective', 'use'), ('distributions', 'use'), ('Fedora', 'use'), ('fixed', 'upstream'), ('kept', 'up-to-date'), ('speeding', 'up'), ('Mercurial', 'until'), ('either', 'unrestricted'), ('large', 'unit'), ('design-by-contract', 'unit'), ('probably', 'unintended'), ('visually', 'uncluttered'), ('duck', 'typing'), ('gradual', 'typing'), ('static', 'typing'), ('long', 'types'), ('varying', 'types'), ('mixed', 'types'), ('dynamically', 'typed'), ('strongly', 'typed'), ('declared', 'type'), ('suitable', 'type'), ('metaclass', 'type'), ('compile-time', 'type'), ('Fraction', 'type'), ('had', 'two'), ('concatenate', 'two'), ('forming', 'tuple'), ('Wikipedia\'"Wikipedia""""Spanningmultiplelines', 'tuple'), ('always', 'true'), ('namea', 'tribute'), ('algorithmic', 'trading'), ('bug', 'tracker'), ('rounds', 'towards'), ('Rounding', 'towards'), ('Related', 'topics'), ('provides', 'tools'), ('far', 'too'), ('prior', 'to'), ('philosophy', 'to'), ('Cross-compilers', 'to'), ('successor', 'to'), ('given', 'to'), ('decided', 'to'), ('appeal', 'to'), ('backported', 'to'), ('postponed', 'to'), ('forward-ported', 'to'), ('transcompiler', 'to'), ('way', 'to'), ('strive', 'to'), ('patches', 'to'), ('translates', 'to'), ('fun', 'to'), ('tribute', 'to'), ('approaches', 'to'), ('refer', 'to'), ('related', 'to'), ('contrast', 'to'), ('difficult', 'to'), ('referred', 'to'), ('meant', 't ...
