# %%
# 自然语言处理

from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import string
import operator

def isCommon(word):
    commonWords = ["the", "be", "and", "of", "a", "in", "to", "have", "it",
        "i", "that", "for", "you", "he", "with", "on", "do", "say", "this",
        "they", "is", "an", "at", "but","we", "his", "from", "that", "not",
        "by", "she", "or", "as", "what", "go", "their","can", "who", "get",
        "if", "would", "her", "all", "my", "make", "about", "know", "will",
        "as", "up", "one", "time", "has", "been", "there", "year", "so",
        "think", "when", "which", "them", "some", "me", "people", "take",
        "out", "into", "just", "see", "him", "your", "come", "could", "now",
        "than", "like", "other", "how", "then", "its", "our", "two", "more",
        "these", "want", "way", "look", "first", "also", "new", "because",
        "day", "more", "use", "no", "man", "find", "here", "thing", "give",
        "many", "well"]    
    if word in commonWords:
        return True
    return False

def cleanInput(input):
    input = re.sub('\n+', " ", input).lower()
    input = re.sub('\[[0-9]*\]', "", input)
    input = re.sub(' +', " ", input)
    input = bytes(input, "UTF-8")
    input = input.decode("ascii", "ignore")
    cleanInput = []
    input = input.split(' ')
    for item in input:
        item = item.strip(string.punctuation)
        if len(item) > 1 or (item.lower() == 'a' or item.lower() == 'i'):
            if isCommon(item) is False:
                cleanInput.append(item)
    return cleanInput

def ngrams(input, n):
    input = cleanInput(input)
    output = {}
    for i in range(len(input)-n+1):
        ngramTemp = " ".join(input[i:i+n])
        if ngramTemp not in output:
            output[ngramTemp] = 0
        output[ngramTemp] += 1
    return output

# %%
content = str(
urlopen("http://pythonscraping.com/files/inaugurationSpeech.txt").read(),
'utf-8')
ngrams = ngrams(content, 2)
sortedNGrams = sorted(ngrams.items(), key = operator.itemgetter(1), reverse=True)
print(sortedNGrams)
# Out:
# [('united states', 10), ('grant power', 4), ('executive power', 4), ('executive department', 4), ('general government', 4), ('spirit liberty', 4), ('called upon', 3), ('chief magistrate', 3), ('was intended', 3), ('framers constitution', 3), ('placed hands', 3), ('mr jefferson', 3), ('those whom', 3), ('acts legislative', 3), ('legislative body', 3), ('upon acts', 3), ('same causes', 3), ('state things', 3), ('government should', 3), ('district columbia', 3), ('whole country', 3), ('principles govern', 2), ('discharge duties', 2), ('upon perform', 2), ('was observable', 2), ('upon part', 2), ('those are', 2), ('power claimed', 2), ('amount power', 2), ('men are', 2), ('express grant', 2), ('constitution united', 2), ('several departments', 2), ('power granted', 2), ('american citizen', 2), ('citizen was', 2), ('prescribed constitution', 2), ('exercise powers', 2), ('carry effect', 2), ('are attributable', 2), ('does appear', 2), ('upon another', 2), ('reserved rights', 2), ('federal government', 2), ('power increase', 2), ('increase itself', 2), ('were made', 2), ('heretofore given', 2), ('pristine health', 2), ('defects constitution', 2), ('second term', 2), ('framed constitution', 2), ('may observed', 2), ('observed however', 2), ('likely produce', 2), ('whom intrusted', 2), ('management foreign', 2), ('foreign relations', 2), ('under circumstances', 2), ('constitution legislative', 2), ('indeed constitution', 2), ('given executive', 2), ('power executive', 2), ('negative upon', 2), ('conformity constitution', 2), ('declare void', 2), ('both houses', 2), ('houses congress', 2), ('legislative executive', 2), ('used only', 2), ('constitution principle', 2), ('state governments', 2), ('immediate representatives', 2), ('tie interest', 2), ('veto power', 2), ('body any', 2), ('had committed', 2), ('feelings was', 2), ('constituted constitution', 2), ('high office', 2), ('disputed points', 2), ('powers respectively', 2), ('respectively claim', 2), ('reserved powers', 2), ('state authorities', 2), ('great increase', 2), ('character government', 2), ('controlling freedom', 2), ('freedom elective', 2), ('elective franchise', 2), ('under control', 2), ('control executive', 2), ('duty president', 2), ('control public', 2), ('strange indeed', 2), ('public money', 2), ('branch legislature', 2), ('means placed', 2), ('civil religious', 2), ('religious liberty', 2), ('should never', 2), ('constitution should', 2), ('propose amendments', 2), ('exclusive metallic', 2), ('metallic currency', 2), ('american citizens', 2), ('departments government', 2), ('any member', 2), ('citizen any', 2), ('powers any', 2), ('control domestic', 2), ('domestic concerns', 2), ('foreign aggression', 2), ('under direction', 2), ('individual members', 2), ('character credit', 2), ('injury institutions', 2), ('liberty spirit', 2), ('roman senate', 2), ('itself upon', 2), ('genuine spirit', 2), ('true spirit', 2), ('spirit party', 2), ('called retirement', 1), ('retirement had', 1), ('had supposed', 1), ('supposed was', 1), ('was continue', 1), ('continue residue', 1), ('residue life', 1), ('life fill', 1), ('fill chief', 1), ('chief executive', 1), ('executive office', 1), ('office great', 1), ('great free', 1), ('free nation', 1), ('nation appear', 1), ('appear before', 1), ('before fellow-citizens', 1), ('fellow-citizens oaths', 1), ('oaths constitution', 1), ('constitution prescribes', 1), ('prescribes necessary', 1), ('necessary qualification', 1), ('qualification performance', 1), ('performance duties', 1), ('duties obedience', 1), ('obedience custom', 1), ('custom coeval', 1), ('coeval government', 1), ('government believe', 1), ('believe expectations', 1), ('expectations proceed', 1), ('proceed present', 1), ('present summary', 1), ('summary principles', 1), ('govern discharge', 1), ('duties shall', 1), ('shall called', 1), ('perform was', 1), ('was remark', 1), ('remark roman', 1), ('roman consul', 1), ('consul early', 1), ('early period', 1), ('period cel ...
