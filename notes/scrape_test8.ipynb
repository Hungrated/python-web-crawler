# %%
# 数据清洗

from urllib.request import urlopen
from bs4 import BeautifulSoup

def ngrams(input, n):
    input = input.split(' ')
    output = []
    for i in range(len(input)-n+1):
        output.append(input[i:i+n])
    return output

html = urlopen("http://en.wikipedia.org/wiki/Python_(programming_language)")
bsObj = BeautifulSoup(html, features='lxml')
content = bsObj.find("div", {"id":"mw-content-text"}).get_text()
ngrams = ngrams(content, 2)
print(ngrams)
print("2-grams count is: "+str(len(ngrams)))
# Out:
# [['Python\nParadigm\nObject-oriented,', 'imperative,'], ['imperative,', 'functional,'], ['functional,', 'procedural,'], ['procedural,', 'reflectiveDesigned\xa0by\nGuido'], ['reflectiveDesigned\xa0by\nGuido', 'van'], ['van', 'RossumDeveloper\nPython'], ['RossumDeveloper\nPython', 'Software'], ['Software', 'FoundationFirst\xa0appeared\n1990;'], ['FoundationFirst\xa0appeared\n1990;', '28\xa0years'], ['28\xa0years', 'ago\xa0(1990)[1]\nStable'], ['ago\xa0(1990)[1]\nStable', 'release\n3.7.0'], ['release\n3.7.0', '/'], ['/', '27\xa0June'], ['27\xa0June', '2018;'], ['2018;', '43'], ['43', 'days'], ['days', 'ago\xa0(2018-06-27)[2]2.7.15'], ['ago\xa0(2018-06-27)[2]2.7.15', '/'], ['/', '1\xa0May'], ['1\xa0May', '2018;'], ['2018;', '3'], ['3', 'months'], ['months', 'ago\xa0(2018-05-01)[3]\n\nTyping'], ['ago\xa0(2018-05-01)[3]\n\nTyping', 'discipline\nDuck,'], ['discipline\nDuck,', 'dynamic,'], ['dynamic,', 'strong\nsince'], ['strong\nsince', 'version'], ['version', '3.5:\n\nGradual[4]License\nPython'], ['3.5:\n\nGradual[4]License\nPython', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions\n.py,'], ['extensions\n.py,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[5]'], ['3.5),[5]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[6]Website\nwww.python.orgMajor'], ['3.5)[6]Website\nwww.python.orgMajor', 'implementations\nCPython,'], ['implementations\nCPython,', 'IronPython,'], ['IronPython,', 'Jython,'], ['Jython,', 'MicroPython,'], ['MicroPython,', 'Numba,'], ['Numba,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'PythonDialects\nCython,'], ['PythonDialects\nCython,', 'RPythonInfluenced'], ['RPythonInfluenced', 'by\nABC,[7]'], ['by\nABC,[7]', 'ALGOL'], ['ALGOL', '68,[8]'], ['68,[8]', 'C,[9]'], ['C,[9]', 'C++,[10]'], ['C++,[10]', 'CLU,[11]'], ['CLU,[11]', 'Dylan,[12]'], ['Dylan,[12]', 'Haskell,[13]'], ['Haskell,[13]', 'Icon,[14]'], ['Icon,[14]', 'Java,[15]'], ['Java,[15]', 'Lisp,[16]'], ['Lisp,[16]', 'Modula-3,[10]'], ['Modula-3,[10]', 'PerlInfluenced\nBoo,'], ['PerlInfluenced\nBoo,', 'Cobra,'], ['Cobra,', ''], ['', 'CoffeeScript,[17]'], ['CoffeeScript,[17]', 'D,'], ['D,', 'F#,'], ['F#,', 'Falcon,'], ['Falcon,', 'Genie,[18]'], ['Genie,[18]', 'Go,'], ['Go,', 'Apache'], ['Apache', 'Groovy,'], ['Groovy,', 'JavaScript,[19][20]'], ['JavaScript,[19][20]', 'Julia,[21]'], ['Julia,[21]', 'Nim,'], ['Nim,', 'Ring,[22]'], ['Ring,[22]', 'Ruby,[23]'], ['Ruby,[23]', 'Swift[24]\n'], ['Swift[24]\n', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks\n\nPython'], ['Wikibooks\n\nPython', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'programming'], ['programming', 'language'], ['language', 'for'], ['for', 'general-purpose'], ['general-purpose', 'programming.'], ['programming.', 'Created'], ['Created', 'by'], ['by', 'Guido'], ['Guido', 'van'], ['van', 'Rossum'], ['Rossum', 'and'], ['and', 'first'], ['first', 'released'], ['released', 'in'], ['in', '1991,'], ['1991,', 'Python'], ['Python', 'has'], ['has', 'a'], ['a', 'design'], ['design', 'philosophy'], ['philosophy', 'that'], ['that', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability,'], ['readability,', 'notably'], ['notably', 'using'], ['using', 'significant'], ['significant', 'whitespace.'], ['whitespace.', 'It'], ['It', 'provides'], ['provides', 'constructs'], ['constructs', 'that'], ['that', 'enable'], ['enable', 'clear'], ['clear', 'programming'], ['programming', 'on'], ['on', 'both'], ['both', 'small'], ['small', 'and'], ['and', 'large'], ['large', 'scales.[25]'], ['scales.[25]', 'In'], ['In', 'July'], ['July', '2018,'], ['2018,', 'Van'], ['Van', 'Rossum'], ['Rossum', 'stepped'], ['stepped', 'down'], ['down', 'as'], ['as', 'the'], ['the', 'leader'], ['leader', 'in'], ['in', 'the'], ['the', 'language'], ['language', 'community'], ['community', 'after'], ['after', '30'], ['30', 'years.[26][ ...
# 2-grams count is: 8764

# %%
import re

content = re.sub('\n+', " ", content)
content = re.sub(' +', " ", content)
content = bytes(content, "UTF-8")
content = content.decode("ascii", "ignore")

def ngrams(input, n):
    
    input = input.split(' ')
    output = []
    for i in range(len(input)-n+1):
        output.append(input[i:i+n])
    return output

ngrams = ngrams(content, 2)
print(ngrams)
print("2-grams count is: "+str(len(ngrams)))
# Out:
# [['Python', 'Paradigm'], ['Paradigm', 'Object-oriented,'], ['Object-oriented,', 'imperative,'], ['imperative,', 'functional,'], ['functional,', 'procedural,'], ['procedural,', 'reflectiveDesignedby'], ['reflectiveDesignedby', 'Guido'], ['Guido', 'van'], ['van', 'RossumDeveloper'], ['RossumDeveloper', 'Python'], ['Python', 'Software'], ['Software', 'FoundationFirstappeared'], ['FoundationFirstappeared', '1990;'], ['1990;', '28years'], ['28years', 'ago(1990)[1]'], ['ago(1990)[1]', 'Stable'], ['Stable', 'release'], ['release', '3.7.0'], ['3.7.0', '/'], ['/', '27June'], ['27June', '2018;'], ['2018;', '43'], ['43', 'days'], ['days', 'ago(2018-06-27)[2]2.7.15'], ['ago(2018-06-27)[2]2.7.15', '/'], ['/', '1May'], ['1May', '2018;'], ['2018;', '3'], ['3', 'months'], ['months', 'ago(2018-05-01)[3]'], ['ago(2018-05-01)[3]', 'Typing'], ['Typing', 'discipline'], ['discipline', 'Duck,'], ['Duck,', 'dynamic,'], ['dynamic,', 'strong'], ['strong', 'since'], ['since', 'version'], ['version', '3.5:'], ['3.5:', 'Gradual[4]License'], ['Gradual[4]License', 'Python'], ['Python', 'Software'], ['Software', 'Foundation'], ['Foundation', 'LicenseFilename'], ['LicenseFilename', 'extensions'], ['extensions', '.py,'], ['.py,', '.pyc,'], ['.pyc,', '.pyd,'], ['.pyd,', '.pyo'], ['.pyo', '(prior'], ['(prior', 'to'], ['to', '3.5),[5]'], ['3.5),[5]', '.pyw,'], ['.pyw,', '.pyz'], ['.pyz', '(since'], ['(since', '3.5)[6]Website'], ['3.5)[6]Website', 'www.python.orgMajor'], ['www.python.orgMajor', 'implementations'], ['implementations', 'CPython,'], ['CPython,', 'IronPython,'], ['IronPython,', 'Jython,'], ['Jython,', 'MicroPython,'], ['MicroPython,', 'Numba,'], ['Numba,', 'PyPy,'], ['PyPy,', 'Stackless'], ['Stackless', 'PythonDialects'], ['PythonDialects', 'Cython,'], ['Cython,', 'RPythonInfluenced'], ['RPythonInfluenced', 'by'], ['by', 'ABC,[7]'], ['ABC,[7]', 'ALGOL'], ['ALGOL', '68,[8]'], ['68,[8]', 'C,[9]'], ['C,[9]', 'C++,[10]'], ['C++,[10]', 'CLU,[11]'], ['CLU,[11]', 'Dylan,[12]'], ['Dylan,[12]', 'Haskell,[13]'], ['Haskell,[13]', 'Icon,[14]'], ['Icon,[14]', 'Java,[15]'], ['Java,[15]', 'Lisp,[16]'], ['Lisp,[16]', 'Modula-3,[10]'], ['Modula-3,[10]', 'PerlInfluenced'], ['PerlInfluenced', 'Boo,'], ['Boo,', 'Cobra,'], ['Cobra,', 'CoffeeScript,[17]'], ['CoffeeScript,[17]', 'D,'], ['D,', 'F#,'], ['F#,', 'Falcon,'], ['Falcon,', 'Genie,[18]'], ['Genie,[18]', 'Go,'], ['Go,', 'Apache'], ['Apache', 'Groovy,'], ['Groovy,', 'JavaScript,[19][20]'], ['JavaScript,[19][20]', 'Julia,[21]'], ['Julia,[21]', 'Nim,'], ['Nim,', 'Ring,[22]'], ['Ring,[22]', 'Ruby,[23]'], ['Ruby,[23]', 'Swift[24]'], ['Swift[24]', 'Python'], ['Python', 'Programming'], ['Programming', 'at'], ['at', 'Wikibooks'], ['Wikibooks', 'Python'], ['Python', 'is'], ['is', 'an'], ['an', 'interpreted'], ['interpreted', 'high-level'], ['high-level', 'programming'], ['programming', 'language'], ['language', 'for'], ['for', 'general-purpose'], ['general-purpose', 'programming.'], ['programming.', 'Created'], ['Created', 'by'], ['by', 'Guido'], ['Guido', 'van'], ['van', 'Rossum'], ['Rossum', 'and'], ['and', 'first'], ['first', 'released'], ['released', 'in'], ['in', '1991,'], ['1991,', 'Python'], ['Python', 'has'], ['has', 'a'], ['a', 'design'], ['design', 'philosophy'], ['philosophy', 'that'], ['that', 'emphasizes'], ['emphasizes', 'code'], ['code', 'readability,'], ['readability,', 'notably'], ['notably', 'using'], ['using', 'significant'], ['significant', 'whitespace.'], ['whitespace.', 'It'], ['It', 'provides'], ['provides', 'constructs'], ['constructs', 'that'], ['that', 'enable'], ['enable', 'clear'], ['clear', 'programming'], ['programming', 'on'], ['on', 'both'], ['both', 'small'], ['small', 'and'], ['and', 'large'], ['large', 'scales.[25]'], ['scales.[25]', 'In'], ['In', 'July'], ['July', '2018,'], ['2018,', 'Van'], ['Van', 'Rossum'], ['Rossum', 'stepped'], ['stepped', 'down'], ['down', 'as'], ['as', 'the'], ['the', 'leader'], ['leader', 'in'], ['in', 'the'], ['the', 'language'], ['language', 'community'], ['commun ...
# 2-grams count is: 9417
